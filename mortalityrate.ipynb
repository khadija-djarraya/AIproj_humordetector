# %% [markdown]
# Task 1

# %%
current_dir = !pwd
print(current_dir)

# List all files in this folder
file_list = !ls
print(file_list)

# List all files in the datasets directory
dataset_list = !ls datasets
print(dataset_list)

# View the first 20 lines of datasets/road-accidents.csv
accidents_head = !head -20 "datasets/dataset.csv"
print(accidents_head)
print(len(accidents_head))
# Out:
# ['/content']
# ['datasets  sample_data']
# ['dataset.csv']
# ...

# %% [markdown]
# Task 2

# %%
# Import the `pandas` module as "pd"

import pandas as pd
# ... YOUR CODE FOR TASK 2 ...

# Read in `road-accidents.csv`
car_acc = pd.read_csv("datasets/dataset.csv", comment="#",sep=",") # comments separated with cardinal, separators
#are comas in the dataset I used

car_acc #output the table

# Save the number of rows columns as a tuple
rows_and_cols = car_acc.shape #shape of the matrix that read the dataset
print('There are {} rows and {} columns.\n'.format(
    rows_and_cols[0], rows_and_cols[1]))

# Generate an overview of the DataFrame
car_acc_information = car_acc.info()

# Display the last five rows of the DataFrame
car_acc.tail(5)
# Out:
# There are 51 rows and 8 columns.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                  --------------  -----
#  0   State                                                                                                   51 non-null     object
#  1   Number of drivers involved in fatal collisions per billion miles                                        51 non-null     float64
#  2   Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding                                    51 non-null     int64
#  3   Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired                            51 non-null     int64
# ...

# %% [markdown]
# Task 3

# %%
# import seaborn and make plots appear inline
import seaborn as sns
# %matplotlib inline

# Compute the summary statistics of all columns in the `car_acc` DataFrame
sum_stat_car = car_acc.describe()
print(sum_stat_car)

# Create a pairwise scatter plot to explore the data
sns.pairplot(car_acc)
# Out:
#        Number of drivers involved in fatal collisions per billion miles  \
# count                                          51.000000
# mean                                           15.790196
# std                                             4.122002
# min                                             5.900000
# 25%                                            12.750000
# 50%                                            15.600000
# 75%                                            18.500000
# max                                            23.900000
#
#        Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding  \
# count                                          51.000000
# mean                                           31.725490
# std                                             9.633438
# min                                            13.000000
# 25%                                            23.000000
# 50%                                            34.000000
# ...

# %% [markdown]
# Task 4

# %%
# Compute the correlation coefficent for all column pairs
corr_columns = car_acc.corr()
corr_columns
# Out:
#                                                     Number of drivers involved in fatal collisions per billion miles  \
# Number of drivers involved in fatal collisions ...                                           1.000000
# Percentage Of Drivers Involved In Fatal Collisi...                                          -0.029080
# Percentage Of Drivers Involved In Fatal Collisi...                                           0.199426
# Percentage Of Drivers Involved In Fatal Collisi...                                           0.009782
# Percentage Of Drivers Involved In Fatal Collisi...                                          -0.017942
# Car Insurance Premiums ($)                                                                  -0.199702
# Losses incurred by insurance companies for coll...                                          -0.036011
#
#                                                     Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding  \
# ...

# %% [markdown]
# Task 5

# %%
# Import the linear model function from sklearn
from sklearn import linear_model

# Create the features and target DataFrames
features = car_acc[["Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding",
                    "Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired",
                    "Percentage Of Drivers Involved In Fatal Collisions Who Were Not Distracted"]]
target = car_acc["Number of drivers involved in fatal collisions per billion miles"]
# Create a linear regression object
reg = linear_model.LinearRegression()
# Fit a multivariate linear regression model
reg.fit(features,target)
# ... YOUR CODE FOR TASK 5 ...

# Retrieve the regression coefficients
fit_coef = reg.coef_
fit_coef
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aafbc95d061d> in <module>
#       3
#       4 # Create the features and target DataFrames
# ----> 5 features = car_acc[["Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding",
#       6                     "Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired",
#       7                     "Percentage Of Drivers Involved In Fatal Collisions Who Were Not Distracted"]]
#
# NameError: name 'car_acc' is not defined
